# %% [markdown]
# # Estatística
#
# ## Histogramas, valor esperado, variância e desvio padrão
#
# - Problema da espera no restaurante
#
# - Variável estocástica
# - Histograma

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Histograma

# %%
# Usei uma massa de dados aleatória

pld_simulado = np.random.normal(size=2000) * 1000

# %%
print('type(pdl_simulado) = ', type(pld_simulado))
print('type(pdl_simulado) = ', len(pld_simulado))
print('type(pdl_simulado) = ', min(pld_simulado))
print('type(pdl_simulado) = ', max(pld_simulado))
# Out:
# type(pdl_simulado) =  <class 'numpy.ndarray'>
# type(pdl_simulado) =  2000
# type(pdl_simulado) =  -2950.359256569984
# type(pdl_simulado) =  3289.583539503234

# %%
plt.hist(pld_simulado)
plt.grid()
plt.show()

# %%
counts, bins = np.histogram(pld_simulado)
print(counts)
print(bins)
# Out:
# [ 14  65 188 355 494 455 263 115  42   9]
# [-2950.35925657 -2326.36497696 -1702.37069736 -1078.37641775
#   -454.38213814   169.61214147   793.60642107  1417.60070068
#   2041.59498029  2665.5892599   3289.5835395 ]
